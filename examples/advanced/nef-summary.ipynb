# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1547292454" href="javascript:toggle_input_1547292454()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1547292454;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1547292454 = document.getElementById("1547292454");
#                 var cell = link_1547292454;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1547292454;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1547292454 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1547292454 = cell.previousElementSibling;
#                 }
#                 input_1547292454.style.display = "none"; // hide
#
#                 toggle_input_1547292454 = function() {
#                     if (input_1547292454.style.display == "none") {
#                         input_1547292454.style.display = ""; // show
#                         link_1547292454.innerHTML = "Hide Input";
#                     } else {
#                         input_1547292454.style.display = "none"; // hide
#                         link_1547292454.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1547292454 = $("a[id='1547292454']");
#                 var cell_1547292454 = link_1547292454.parents("div.cell:first");
#                 if (cell_1547292454.length == 0) {
#                     cell_1547292454 = link_1547292454.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1547292454 = cell_1547292454.children("div.input");
#                 if (input_1547292454.length == 0) {
#                     input_1547292454 = cell_1547292454.prev("div.nbinput");
#                 }
#                 input_1547292454.hide();
#
#                 toggle_input_1547292454 = function() {
#                     if (input_1547292454.is(':hidden')) {
#                         input_1547292454.slideDown();
#                         link_1547292454[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1547292454.slideUp();
#                         link_1547292454[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1);
hide_input()
# Out:
#         <a id="923667293" href="javascript:toggle_input_923667293()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_923667293;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_923667293 = document.getElementById("923667293");
#                 var cell = link_923667293;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_923667293;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_923667293 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_923667293 = cell.previousElementSibling;
#                 }
#                 input_923667293.style.display = "none"; // hide
#
#                 toggle_input_923667293 = function() {
#                     if (input_923667293.style.display == "none") {
#                         input_923667293.style.display = ""; // show
#                         link_923667293.innerHTML = "Hide Input";
#                     } else {
#                         input_923667293.style.display = "none"; // hide
#                         link_923667293.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_923667293 = $("a[id='923667293']");
#                 var cell_923667293 = link_923667293.parents("div.cell:first");
#                 if (cell_923667293.length == 0) {
#                     cell_923667293 = link_923667293.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_923667293 = cell_923667293.children("div.input");
#                 if (input_923667293.length == 0) {
#                     input_923667293 = cell_923667293.prev("div.nbinput");
#                 }
#                 input_923667293.hide();
#
#                 toggle_input_923667293 = function() {
#                     if (input_923667293.is(':hidden')) {
#                         input_923667293.slideDown();
#                         link_923667293[0].innerHTML = "Hide Input";
#                     } else {
#                         input_923667293.slideUp();
#                         link_923667293[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders)

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");
hide_input()
# Out:
#         <a id="1781082864" href="javascript:toggle_input_1781082864()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1781082864;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1781082864 = document.getElementById("1781082864");
#                 var cell = link_1781082864;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1781082864;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1781082864 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1781082864 = cell.previousElementSibling;
#                 }
#                 input_1781082864.style.display = "none"; // hide
#
#                 toggle_input_1781082864 = function() {
#                     if (input_1781082864.style.display == "none") {
#                         input_1781082864.style.display = ""; // show
#                         link_1781082864.innerHTML = "Hide Input";
#                     } else {
#                         input_1781082864.style.display = "none"; // hide
#                         link_1781082864.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1781082864 = $("a[id='1781082864']");
#                 var cell_1781082864 = link_1781082864.parents("div.cell:first");
#                 if (cell_1781082864.length == 0) {
#                     cell_1781082864 = link_1781082864.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1781082864 = cell_1781082864.children("div.input");
#                 if (input_1781082864.length == 0) {
#                     input_1781082864 = cell_1781082864.prev("div.nbinput");
#                 }
#                 input_1781082864.hide();
#
#                 toggle_input_1781082864 = function() {
#                     if (input_1781082864.is(':hidden')) {
#                         input_1781082864.slideDown();
#                         link_1781082864[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1781082864.slideUp();
#                         link_1781082864[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)');
hide_input()
# Out:
#         <a id="1986698825" href="javascript:toggle_input_1986698825()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1986698825;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1986698825 = document.getElementById("1986698825");
#                 var cell = link_1986698825;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1986698825;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1986698825 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1986698825 = cell.previousElementSibling;
#                 }
#                 input_1986698825.style.display = "none"; // hide
#
#                 toggle_input_1986698825 = function() {
#                     if (input_1986698825.style.display == "none") {
#                         input_1986698825.style.display = ""; // show
#                         link_1986698825.innerHTML = "Hide Input";
#                     } else {
#                         input_1986698825.style.display = "none"; // hide
#                         link_1986698825.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1986698825 = $("a[id='1986698825']");
#                 var cell_1986698825 = link_1986698825.parents("div.cell:first");
#                 if (cell_1986698825.length == 0) {
#                     cell_1986698825 = link_1986698825.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1986698825 = cell_1986698825.children("div.input");
#                 if (input_1986698825.length == 0) {
#                     input_1986698825 = cell_1986698825.prev("div.nbinput");
#                 }
#                 input_1986698825.hide();
#
#                 toggle_input_1986698825 = function() {
#                     if (input_1986698825.is(':hidden')) {
#                         input_1986698825.slideDown();
#                         link_1986698825[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1986698825.slideUp();
#                         link_1986698825[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(8, dimensions=1,
                       intercepts=intercepts,
                       max_rates=Uniform(80, 100),
                       encoders=encoders)
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale),
    np.arange(A.n_neurons))
hide_input()
# Out:
#         <a id="1403131065" href="javascript:toggle_input_1403131065()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1403131065;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1403131065 = document.getElementById("1403131065");
#                 var cell = link_1403131065;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1403131065;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1403131065 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1403131065 = cell.previousElementSibling;
#                 }
#                 input_1403131065.style.display = "none"; // hide
#
#                 toggle_input_1403131065 = function() {
#                     if (input_1403131065.style.display == "none") {
#                         input_1403131065.style.display = ""; // show
#                         link_1403131065.innerHTML = "Hide Input";
#                     } else {
#                         input_1403131065.style.display = "none"; // hide
#                         link_1403131065.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1403131065 = $("a[id='1403131065']");
#                 var cell_1403131065 = link_1403131065.parents("div.cell:first");
#                 if (cell_1403131065.length == 0) {
#                     cell_1403131065 = link_1403131065.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1403131065 = cell_1403131065.children("div.input");
#                 if (input_1403131065.length == 0) {
#                     input_1403131065 = cell_1403131065.prev("div.nbinput");
#                 }
#                 input_1403131065.hide();
#
#                 toggle_input_1403131065 = function() {
#                     if (input_1403131065.is(':hidden')) {
#                         input_1403131065.slideDown();
#                         link_1403131065[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1403131065.slideUp();
#                         link_1403131065[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1193966548" href="javascript:toggle_input_1193966548()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1193966548;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1193966548 = document.getElementById("1193966548");
#                 var cell = link_1193966548;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1193966548;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1193966548 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1193966548 = cell.previousElementSibling;
#                 }
#                 input_1193966548.style.display = "none"; // hide
#
#                 toggle_input_1193966548 = function() {
#                     if (input_1193966548.style.display == "none") {
#                         input_1193966548.style.display = ""; // show
#                         link_1193966548.innerHTML = "Hide Input";
#                     } else {
#                         input_1193966548.style.display = "none"; // hide
#                         link_1193966548.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1193966548 = $("a[id='1193966548']");
#                 var cell_1193966548 = link_1193966548.parents("div.cell:first");
#                 if (cell_1193966548.length == 0) {
#                     cell_1193966548 = link_1193966548.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1193966548 = cell_1193966548.children("div.input");
#                 if (input_1193966548.length == 0) {
#                     input_1193966548 = cell_1193966548.prev("div.nbinput");
#                 }
#                 input_1193966548.hide();
#
#                 toggle_input_1193966548 = function() {
#                     if (input_1193966548.is(':hidden')) {
#                         input_1193966548.slideDown();
#                         link_1193966548[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1193966548.slideUp();
#                         link_1193966548[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="347964047" href="javascript:toggle_input_347964047()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_347964047;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_347964047 = document.getElementById("347964047");
#                 var cell = link_347964047;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_347964047;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_347964047 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_347964047 = cell.previousElementSibling;
#                 }
#                 input_347964047.style.display = "none"; // hide
#
#                 toggle_input_347964047 = function() {
#                     if (input_347964047.style.display == "none") {
#                         input_347964047.style.display = ""; // show
#                         link_347964047.innerHTML = "Hide Input";
#                     } else {
#                         input_347964047.style.display = "none"; // hide
#                         link_347964047.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_347964047 = $("a[id='347964047']");
#                 var cell_347964047 = link_347964047.parents("div.cell:first");
#                 if (cell_347964047.length == 0) {
#                     cell_347964047 = link_347964047.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_347964047 = cell_347964047.children("div.input");
#                 if (input_347964047.length == 0) {
#                     input_347964047 = cell_347964047.prev("div.nbinput");
#                 }
#                 input_347964047.hide();
#
#                 toggle_input_347964047 = function() {
#                     if (input_347964047.is(':hidden')) {
#                         input_347964047.slideDown();
#                         link_347964047[0].innerHTML = "Hide Input";
#                     } else {
#                         input_347964047.slideUp();
#                         link_347964047[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1983833417" href="javascript:toggle_input_1983833417()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1983833417;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1983833417 = document.getElementById("1983833417");
#                 var cell = link_1983833417;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1983833417;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1983833417 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1983833417 = cell.previousElementSibling;
#                 }
#                 input_1983833417.style.display = "none"; // hide
#
#                 toggle_input_1983833417 = function() {
#                     if (input_1983833417.style.display == "none") {
#                         input_1983833417.style.display = ""; // show
#                         link_1983833417.innerHTML = "Hide Input";
#                     } else {
#                         input_1983833417.style.display = "none"; // hide
#                         link_1983833417.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1983833417 = $("a[id='1983833417']");
#                 var cell_1983833417 = link_1983833417.parents("div.cell:first");
#                 if (cell_1983833417.length == 0) {
#                     cell_1983833417 = link_1983833417.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1983833417 = cell_1983833417.children("div.input");
#                 if (input_1983833417.length == 0) {
#                     input_1983833417 = cell_1983833417.prev("div.nbinput");
#                 }
#                 input_1983833417.hide();
#
#                 toggle_input_1983833417 = function() {
#                     if (input_1983833417.is(':hidden')) {
#                         input_1983833417.slideDown();
#                         link_1983833417[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1983833417.slideUp();
#                         link_1983833417[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input, )
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(
    sim.trange(),
    sim.data[input_probe],
    label="Input signal")
plt.plot(
    sim.trange(),
    sim.data[Asquare_probe],
    label="Decoded esimate")
plt.plot(
    sim.trange(),
    np.square(sim.data[input_probe]),
    label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1615487432" href="javascript:toggle_input_1615487432()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1615487432;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1615487432 = document.getElementById("1615487432");
#                 var cell = link_1615487432;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1615487432;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1615487432 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1615487432 = cell.previousElementSibling;
#                 }
#                 input_1615487432.style.display = "none"; // hide
#
#                 toggle_input_1615487432 = function() {
#                     if (input_1615487432.style.display == "none") {
#                         input_1615487432.style.display = ""; // show
#                         link_1615487432.innerHTML = "Hide Input";
#                     } else {
#                         input_1615487432.style.display = "none"; // hide
#                         link_1615487432.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1615487432 = $("a[id='1615487432']");
#                 var cell_1615487432 = link_1615487432.parents("div.cell:first");
#                 if (cell_1615487432.length == 0) {
#                     cell_1615487432 = link_1615487432.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1615487432 = cell_1615487432.children("div.input");
#                 if (input_1615487432.length == 0) {
#                     input_1615487432 = cell_1615487432.prev("div.nbinput");
#                 }
#                 input_1615487432.hide();
#
#                 toggle_input_1615487432 = function() {
#                     if (input_1615487432.is(':hidden')) {
#                         input_1615487432.slideDown();
#                         link_1615487432[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1615487432.slideUp();
#                         link_1615487432[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1803952808" href="javascript:toggle_input_1803952808()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1803952808;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1803952808 = document.getElementById("1803952808");
#                 var cell = link_1803952808;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1803952808;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1803952808 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1803952808 = cell.previousElementSibling;
#                 }
#                 input_1803952808.style.display = "none"; // hide
#
#                 toggle_input_1803952808 = function() {
#                     if (input_1803952808.style.display == "none") {
#                         input_1803952808.style.display = ""; // show
#                         link_1803952808.innerHTML = "Hide Input";
#                     } else {
#                         input_1803952808.style.display = "none"; // hide
#                         link_1803952808.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1803952808 = $("a[id='1803952808']");
#                 var cell_1803952808 = link_1803952808.parents("div.cell:first");
#                 if (cell_1803952808.length == 0) {
#                     cell_1803952808 = link_1803952808.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1803952808 = cell_1803952808.children("div.input");
#                 if (input_1803952808.length == 0) {
#                     input_1803952808 = cell_1803952808.prev("div.nbinput");
#                 }
#                 input_1803952808.hide();
#
#                 toggle_input_1803952808 = function() {
#                     if (input_1803952808.is(':hidden')) {
#                         input_1803952808.slideDown();
#                         link_1803952808[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1803952808.slideUp();
#                         link_1803952808[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1225289205" href="javascript:toggle_input_1225289205()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1225289205;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1225289205 = document.getElementById("1225289205");
#                 var cell = link_1225289205;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1225289205;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1225289205 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1225289205 = cell.previousElementSibling;
#                 }
#                 input_1225289205.style.display = "none"; // hide
#
#                 toggle_input_1225289205 = function() {
#                     if (input_1225289205.style.display == "none") {
#                         input_1225289205.style.display = ""; // show
#                         link_1225289205.innerHTML = "Hide Input";
#                     } else {
#                         input_1225289205.style.display = "none"; // hide
#                         link_1225289205.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1225289205 = $("a[id='1225289205']");
#                 var cell_1225289205 = link_1225289205.parents("div.cell:first");
#                 if (cell_1225289205.length == 0) {
#                     cell_1225289205 = link_1225289205.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1225289205 = cell_1225289205.children("div.input");
#                 if (input_1225289205.length == 0) {
#                     input_1225289205 = cell_1225289205.prev("div.nbinput");
#                 }
#                 input_1225289205.hide();
#
#                 toggle_input_1225289205 = function() {
#                     if (input_1225289205.is(':hidden')) {
#                         input_1225289205.slideDown();
#                         link_1225289205[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1225289205.slideUp();
#                         link_1225289205[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="2062985026" href="javascript:toggle_input_2062985026()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2062985026;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2062985026 = document.getElementById("2062985026");
#                 var cell = link_2062985026;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2062985026;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2062985026 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2062985026 = cell.previousElementSibling;
#                 }
#                 input_2062985026.style.display = "none"; // hide
#
#                 toggle_input_2062985026 = function() {
#                     if (input_2062985026.style.display == "none") {
#                         input_2062985026.style.display = ""; // show
#                         link_2062985026.innerHTML = "Hide Input";
#                     } else {
#                         input_2062985026.style.display = "none"; // hide
#                         link_2062985026.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2062985026 = $("a[id='2062985026']");
#                 var cell_2062985026 = link_2062985026.parents("div.cell:first");
#                 if (cell_2062985026.length == 0) {
#                     cell_2062985026 = link_2062985026.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2062985026 = cell_2062985026.children("div.input");
#                 if (input_2062985026.length == 0) {
#                     input_2062985026 = cell_2062985026.prev("div.nbinput");
#                 }
#                 input_2062985026.hide();
#
#                 toggle_input_2062985026 = function() {
#                     if (input_2062985026.is(':hidden')) {
#                         input_2062985026.slideDown();
#                         link_2062985026[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2062985026.slideUp();
#                         link_2062985026[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(
        oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
hide_input()
# Out:
#         <a id="2083107167" href="javascript:toggle_input_2083107167()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2083107167;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2083107167 = document.getElementById("2083107167");
#                 var cell = link_2083107167;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2083107167;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2083107167 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2083107167 = cell.previousElementSibling;
#                 }
#                 input_2083107167.style.display = "none"; // hide
#
#                 toggle_input_2083107167 = function() {
#                     if (input_2083107167.style.display == "none") {
#                         input_2083107167.style.display = ""; // show
#                         link_2083107167.innerHTML = "Hide Input";
#                     } else {
#                         input_2083107167.style.display = "none"; // hide
#                         link_2083107167.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2083107167 = $("a[id='2083107167']");
#                 var cell_2083107167 = link_2083107167.parents("div.cell:first");
#                 if (cell_2083107167.length == 0) {
#                     cell_2083107167 = link_2083107167.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2083107167 = cell_2083107167.children("div.input");
#                 if (input_2083107167.length == 0) {
#                     input_2083107167 = cell_2083107167.prev("div.nbinput");
#                 }
#                 input_2083107167.hide();
#
#                 toggle_input_2083107167 = function() {
#                     if (input_2083107167.is(':hidden')) {
#                         input_2083107167.slideDown();
#                         link_2083107167[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2083107167.slideUp();
#                         link_2083107167[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
